# %%
import pandas as pd

# 读取文件中的某些类数据
df=pd.read_csv(r'C:\Users\24202\Desktop\Test\爬虫\csv_data\movie_list2.csv',usecols=['电影名','年份','评分','语言','时长'])

# 数据处理
df['瞎算']=df['年份']+df['时长']
df

# 写入数据------index=False:不写入索引列
df.to_csv(r'C:\Users\24202\Desktop\Test\爬虫\数据分析\movie_list3.csv',index=False)
